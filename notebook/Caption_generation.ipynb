# %% [markdown]
# ### Importing the tsv file and desining the API endpoint

# %%
import pandas as pd
import requests

# Define the endpoint for the captioning Docker service.
# Make sure this matches your container’s host port and endpoint.
# In our case, if the container is running on host port 8765:
CAPTION_ENDPOINT = "http://localhost:8765/inception/v3/caption/image"

# Update this with the path to your input TSV file.
input_tsv = "arcgis_img_captions_objects-Copy1.tsv"  # e.g., "/Users/lancedsilva/Downloads/haunted_places.tsv"
# output_tsv = "/path/to/your/output_file.tsv"  # e.g., "/Users/lancedsilva/Downloads/haunted_places_updated.tsv"

# Read the TSV file
df = pd.read_csv(input_tsv, sep="\t")

# %%
df2 = df.iloc[:,:]
display(df2.shape)
display(df2)
# Out:
# (9731, 36)
#                city        country  \
# 0               Ada  United States
# 1           Addison  United States
# 2            Adrian  United States
# 3            Adrian  United States
# 4            Albion  United States
# ...             ...            ...
# 9726    Westminster  United States
# 9727    Westminster  United States
# 9728    Wheat Ridge  United States
# 9729    Wheat Ridge  United States
# 9730  Woodland Park  United States
#
#                                             description  \
# 0     Ada witch - Sometimes you can see a misty blue...
# 1     A little girl was killed suddenly while waitin...
# 2     If you take Gorman Rd. west towards Sand Creek...
# 3     In the 1970's, one room, room 211, in the old ...
# 4     Kappa Delta Sorority - The Kappa Delta Sororit...
# ...                                                 ...
# 9726  at 12 midnight you can see a lady with two lit...
# 9727  Is haunted by the victims of a murder that hap...
# 9728  The institution was for kids 18 years old and ...
# 9729  Gymnasium -  their have been reports of a litt...
# 9730  Cadets from the Air Force Academy participatin...
#
#                        location     state state_abbrev   longitude   latitude  \
# 0                  Ada Cemetery  Michigan           MI  -85.504893  42.962106
# 1               North Adams Rd.  Michigan           MI  -84.381843  41.971425
# 2                 Ghost Trestle  Michigan           MI  -84.035656  41.904538
# 3      Siena Heights University  Michigan           MI  -84.017565  41.905712
# 4                Albion College  Michigan           MI  -84.745177  42.244006
# ...                         ...       ...          ...         ...        ...
# 9726                  city hall  Colorado           CO -105.048936  39.862610
# 9727             Pillar of Fire  Colorado           CO -105.032091  39.847237
# 9728   Ridge Mental Institution  Colorado           CO -105.063974  39.769726
# 9729  Wheat Ridge Middle School  Colorado           CO -105.103613  39.764055
# 9730         Saylor Park Forest  Colorado           CO -105.022763  39.116658
#
#       city_longitude  city_latitude  ...   Avg_PRCP   Avg_SNWD  \
# 0         -85.495480      42.960727  ...  21.534207  14.889049
# 1         -84.347168      41.986434  ...  23.936324   5.131693
# 2         -84.037166      41.897547  ...  24.174107   3.531884
# 3         -84.037166      41.897547  ...  24.174107   3.531884
# 4         -84.753030      42.243097  ...  23.936324   5.131693
# ...              ...            ...  ...        ...        ...
# 9726     -105.037205      39.836653  ...  14.987448  13.241283
# 9727     -105.037205      39.836653  ...  14.987448  13.241283
# 9728     -105.077206      39.766098  ...  14.987448  13.241283
# 9729     -105.077206      39.766098  ...  14.987448  13.241283
# 9730     -105.056930      38.993881  ...  11.293463   7.768802
#
#       Diurnal Temperature Range (DTR) intrastate_gaspipe_within_10miles  \
# 0                          119.184638                             False
# 1                          116.806078                             False
# 2                          117.425321                             False
# 3                          117.425321                             False
# 4                          116.806078                              True
# ...                               ...                               ...
# 9726                       157.600397                             False
# 9727                       157.600397                             False
# 9728                       157.600397                             False
# 9729                       157.600397                             False
# 9730                       164.047354                             False
#
#      interstate_gaspipe_within_10miles mental_health_provider  \
# 0                                False                  677.0
# 1                                False                  677.0
# 2                                False                  677.0
# 3                                False                  677.0
# 4                                False                  677.0
# ...                                ...                    ...
# 9726                             False                  457.0
# 9727                             False                  457.0
# 9728                             False                  457.0
# 9729                             False                  457.0
# 9730                             False                  457.0
#
#                                   mental_health_RGB               IMG_LOC  \
# 0     (np.int64(187), np.int64(204), np.int64(199))     Image/image_0.png
# 1     (np.int64(187), np.int64(204), np.int64(199))     Image/image_1.png
# 2     (np.int64(187), np.int64(204), np.int64(199))     Image/image_2.png
# 3     (np.int64(187), np.int64(204), np.int64(199))     Image/image_3.png
# 4     (np.int64(187), np.int64(204), np.int64(199))     Image/image_4.png
# ...                                             ...                   ...
# 9726  (np.int64(139), np.int64(197), np.int64(196))  Image/image_9726.png
# 9727  (np.int64(139), np.int64(197), np.int64(196))  Image/image_9727.png
# 9728  (np.int64(139), np.int64(197), np.int64(196))  Image/image_9728.png
# 9729  (np.int64(139), np.int64(197), np.int64(196))  Image/image_9729.png
# 9730  (np.int64(139), np.int64(197), np.int64(196))  Image/image_9730.png
#
#                                                 caption  \
# 0         a woman standing next to a red fire hydrant .
# 1             a woman standing next to a fire hydrant .
# 2      a park bench sitting in the middle of a forest .
# 3               a black and white photo of a bathroom .
# 4           a black and white photo of a brick building
# ...                                                 ...
# 9726  a large building with a clock on the front of ...
# 9727  a large building with a clock on the front of ...
# 9728       a black and white photo of a train station .
# 9729       a group of people playing a game of tennis .
# 9730    a herd of sheep grazing on a lush green field .
#
#                                                 objects
# 0                 megalith, megalithic structure, cloak
# 1                                           trench coat
# 2     bannister, banister, balustrade, balusters, ha...
# 3                                    safe, sliding door
# 4       paddlewheel, paddle wheel, prison, prison house
# ...                                                 ...
# 9726                                             castle
# 9727                                   monastery, vault
# 9728                      prison, prison house, viaduct
# 9729                             basketball, volleyball
# 9730             whippet, dogsled, dog sled, dog sleigh
#
# [9731 rows x 36 columns]

# %%
display(df2.loc[1249,:])
# Out:
# city                                                                        Wilmington
# country                                                                  United States
# description                          An apparition of a blond blue-eyed man has bee...
# location                                                                 Drum Barracks
# state                                                                       California
# state_abbrev                                                                        CA
# longitude                                                                   -118.25757
# latitude                                                                     33.784471
# city_longitude                                                             -118.264357
# city_latitude                                                                33.785795
# date_occured                                                                2025-01-01
# Audio                                                                            False
# Visual                                                                            True
# Time of Day                                                                    Unknown
# Apparition Type                                                                  Ghost
# Event Type                                                                     Unknown
# witness count                                                                        0
# total_deaths                                                                   15443.0
# %_under_21                                                                       0.025
# daylight_minutes                                                                 815.0
# daylight_diff                                                                    105.2
# geometry                                POINT (-13164372.474849906 3999898.3322308464)
# buffer_10_miles                      POLYGON ((-13148279.074849905 3999898.33223084...
# schools_within_10_miles                                                            226
# distance_to_nearest_school_km                                                 0.518873
# is_haunted_place_a_school                                                           No
# Avg_PRCP                                                                     14.634921
# Avg_SNWD                                                                           NaN
# Diurnal Temperature Range (DTR)                                             127.688312
# intrastate_gaspipe_within_10miles                                                False
# interstate_gaspipe_within_10miles                                                False
# mental_health_provider                                                           450.0
# mental_health_RGB                        (np.int64(143), np.int64(196), np.int64(194))
# IMG_LOC                                                           Image/image_1249.png
# caption                                                                            NaN
# Name: 1249, dtype: object

# %% [markdown]
# ### Code for generating caption for images by first calling HTML file server and then docker container

# %%
import pandas as pd
import requests

# Define the captioning endpoint (for the docker container running the captioning service)
CAPTION_ENDPOINT = "http://localhost:8765/inception/v3/caption/image"


# Create a new column for the caption if it doesn't already exist.
if "caption" not in df2.columns:
    df2.loc[:,"caption"] = ""

def get_caption(image_url):
    """
    Given a shortened image URL (e.g., "Images/image_0.png"), extract the filename 
    and construct the full URL for the local HTTP server before requesting a caption.
    """
    # Remove directory prefix and keep only the filename.
    filename = image_url.split("/")[-1]
    # Build the full URL using only the filename.
    full_url = "http://host.docker.internal:8000/" + filename
    print(full_url)

    params = {
        "url": full_url,
        "beam_size": 3,
        "max_caption_length": 30
    }
    try:
        response = requests.get(CAPTION_ENDPOINT, params=params, timeout=10)
        response.raise_for_status()  # Raise an error if status is not 200
        data = response.json()
        if "captions" in data and isinstance(data["captions"], list) and len(data["captions"]) > 0:
            # print(data["captions"])
            best_caption = max(data["captions"], key=lambda cap: float(cap.get("confidence", 0)))
            # print(best_caption)
            return best_caption['sentence']
        else:
            print("Unexpected JSON structure for image URL:", full_url)
            return ""
    except Exception as e:
        print(f"Error getting caption for image {full_url}: {e}")
        return ""


# Update each row: apply the get_caption function on the IMG_LOC column.
df2.loc[1249, "caption"] = get_caption(df2.loc[1249, "IMG_LOC"])

# # Optionally, save the updated DataFrame to a new TSV file.
# output_tsv = "/path/to/your/haunted_places_updated.tsv"
# df2.to_csv(output_tsv, sep="\t", index=False)
# print("Captions updated and saved to", output_tsv)
# Out:
# http://host.docker.internal:8000/image_1249.png

# %% [markdown]
# ### Generating again for missed images

# %%
numbers = [
    2259, 2477, 2713, 2781,
    3563, 3860, 3957, 4014, 4336, 4900,
    5324, 6197, 6515, 6686, 6759, 6844,
    6910, 6913, 7041, 7865, 8372, 8747,
    9388, 9582
]
for num in numbers:
    df2.loc[num, "caption"] = get_caption(df2.loc[num, "IMG_LOC"])
# Out:
# http://host.docker.internal:8000/image_2259.png
# http://host.docker.internal:8000/image_2477.png
# http://host.docker.internal:8000/image_2713.png
# http://host.docker.internal:8000/image_2781.png
# http://host.docker.internal:8000/image_3563.png
# http://host.docker.internal:8000/image_3860.png
# http://host.docker.internal:8000/image_3957.png
# http://host.docker.internal:8000/image_4014.png
# http://host.docker.internal:8000/image_4336.png
# http://host.docker.internal:8000/image_4900.png
# http://host.docker.internal:8000/image_5324.png
# http://host.docker.internal:8000/image_6197.png
# http://host.docker.internal:8000/image_6515.png
# http://host.docker.internal:8000/image_6686.png
# http://host.docker.internal:8000/image_6759.png
# http://host.docker.internal:8000/image_6844.png
# http://host.docker.internal:8000/image_6910.png
# http://host.docker.internal:8000/image_6913.png
# http://host.docker.internal:8000/image_7041.png
# http://host.docker.internal:8000/image_7865.png
# http://host.docker.internal:8000/image_8372.png
# http://host.docker.internal:8000/image_8747.png
# http://host.docker.internal:8000/image_9388.png
# http://host.docker.internal:8000/image_9582.png

# %%
display(df2.loc[:,'caption'].isna().sum())
# Out:
# np.int64(0)

# %%
# output_tsv = "/path/to/your/haunted_places_updated.tsv"
df2.to_csv('arcgis_img2_captions.tsv', sep="\t", index=False)

# %% [markdown]
# ### Code for generating caption for images by first calling HTML file server and then docker container

# %%
import pandas as pd
import requests

# Define the endpoints for the captioning and object detection services.
OBJECT_ENDPOINT  = "http://localhost:8764/inception/v4/classify/image"

# Create new columns for caption and objects if they don't already exist.
if "objects" not in df2.columns:
    df2.loc[:, "objects"] = ""

def get_objects(image_url):
    """
    Constructs the full URL from the shortened image URL and requests object detection.
    Returns the detected class names as a comma-separated string.
    """
    # Extract the filename.
    filename = image_url.split("/")[-1]
    full_url = "http://host.docker.internal:8000/" + filename
    print("Objects full URL:", full_url)
    
    # Optional: you can add parameters like topn and min_confidence if supported.
    params = {
        "url": full_url,
        "topn": 2,
        "min_confidence": 0.03
    }
    try:
        response = requests.get(OBJECT_ENDPOINT, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        if "classnames" in data and isinstance(data["classnames"], list):
            # Join the class names with commas.
            return ", ".join(data["classnames"])
        else:
            print("Unexpected JSON structure for object detection for URL:", full_url)
            return ""
    except Exception as e:
        print(f"Error getting objects for image {full_url}: {e}")
        return ""

# Update each row in the DataFrame by applying the functions on the IMG_LOC column.
df2.loc[:, "objects"] = df2["IMG_LOC"].apply(get_objects)
# Out:
# Objects full URL: http://host.docker.internal:8000/image_0.png
# Objects full URL: http://host.docker.internal:8000/image_1.png
# Objects full URL: http://host.docker.internal:8000/image_2.png
# Objects full URL: http://host.docker.internal:8000/image_3.png
# Objects full URL: http://host.docker.internal:8000/image_4.png
# Objects full URL: http://host.docker.internal:8000/image_5.png
# Objects full URL: http://host.docker.internal:8000/image_6.png
# Objects full URL: http://host.docker.internal:8000/image_7.png
# Objects full URL: http://host.docker.internal:8000/image_8.png
# Objects full URL: http://host.docker.internal:8000/image_9.png
# Objects full URL: http://host.docker.internal:8000/image_10.png
# Objects full URL: http://host.docker.internal:8000/image_11.png
# Objects full URL: http://host.docker.internal:8000/image_12.png
# Objects full URL: http://host.docker.internal:8000/image_13.png
# Objects full URL: http://host.docker.internal:8000/image_14.png
# Objects full URL: http://host.docker.internal:8000/image_15.png
# Objects full URL: http://host.docker.internal:8000/image_16.png
# Objects full URL: http://host.docker.internal:8000/image_17.png
# Objects full URL: http://host.docker.internal:8000/image_18.png
# Objects full URL: http://host.docker.internal:8000/image_19.png
# Objects full URL: http://host.docker.internal:8000/image_20.png
# Objects full URL: http://host.docker.internal:8000/image_21.png
# Objects full URL: http://host.docker.internal:8000/image_22.png
# Objects full URL: http://host.docker.internal:8000/image_23.png
# Objects full URL: http://host.docker.internal:8000/image_24.png
# Objects full URL: http://host.docker.internal:8000/image_25.png
# Objects full URL: http://host.docker.internal:8000/image_26.png
# Objects full URL: http://host.docker.internal:8000/image_27.png
# Objects full URL: http://host.docker.internal:8000/image_28.png
# Objects full URL: http://host.docker.internal:8000/image_29.png
# Objects full URL: http://host.docker.internal:8000/image_30.png
# Objects full URL: http://host.docker.internal:8000/image_31.png
# Objects full URL: http://host.docker.internal:8000/image_32.png
# Objects full URL: http://host.docker.internal:8000/image_33.png
# Objects full URL: http://host.docker.internal:8000/image_34.png
# Objects full URL: http://host.docker.internal:8000/image_35.png
# Objects full URL: http://host.docker.internal:8000/image_36.png
# Objects full URL: http://host.docker.internal:8000/image_37.png
# Objects full URL: http://host.docker.internal:8000/image_38.png
# Objects full URL: http://host.docker.internal:8000/image_39.png
# Objects full URL: http://host.docker.internal:8000/image_40.png
# Objects full URL: http://host.docker.internal:8000/image_41.png
# Objects full URL: http://host.docker.internal:8000/image_42.png
# Objects full URL: http://host.docker.internal:8000/image_43.png
# Objects full URL: http://host.docker.internal:8000/image_44.png
# Objects full URL: http://host.docker.internal:8000/image_45.png
# Objects full URL: http://host.docker.internal:8000/image_46.png
# Objects full URL: http://host.docker.internal:8000/image_47.png
# Objects full URL: http://host.docker.internal:8000/image_48.png
# Objects full URL: http://host.docker.internal:8000/image_49.png
# Objects full URL: http://host.docker.internal:8000/image_50.png
# Objects full URL: http://host.docker.internal:8000/image_51.png
# Objects full URL: http://host.docker.internal:8000/image_52.png
# Objects full URL: http://host.docker.internal:8000/image_53.png
# Objects full URL: http://host.docker.internal:8000/image_54.png
# Objects full URL: http://host.docker.internal:8000/image_55.png
# Objects full URL: http://host.docker.internal:8000/image_56.png
# Objects full URL: http://host.docker.internal:8000/image_57.png
# Objects full URL: http://host.docker.internal:8000/image_58.png
# Objects full URL: http://host.docker.internal:8000/image_59.png
# Objects full URL: http://host.docker.internal:8000/image_60.png
# Objects full URL: http://host.docker.internal:8000/image_61.png
# Objects full URL: http://host.docker.internal:8000/image_62.png
# Objects full URL: http://host.docker.internal:8000/image_63.png
# Objects full URL: http://host.docker.internal:8000/image_64.png
# Objects full URL: http://host.docker.internal:8000/image_65.png
# Objects full URL: http://host.docker.internal:8000/image_66.png
# Objects full URL: http://host.docker.internal:8000/image_67.png
# Objects full URL: http://host.docker.internal:8000/image_68.png
# Objects full URL: http://host.docker.internal:8000/image_69.png
# Objects full URL: http://host.docker.internal:8000/image_70.png
# Objects full URL: http://host.docker.internal:8000/image_71.png
# Objects full URL: http://host.docker.internal:8000/image_72.png
# Objects full URL: http://host.docker.internal:8000/image_73.png
# Objects full URL: http://host.docker.internal:8000/image_74.png
# Objects full URL: http://host.docker.internal:8000/image_75.png
# Objects full URL: http://host.docker.internal:8000/image_76.png
# Objects full URL: http://host.docker.internal:8000/image_77.png
# Objects full URL: http://host.docker.internal:8000/image_78.png
# Objects full URL: http://host.docker.internal:8000/image_79.png
# Objects full URL: http://host.docker.internal:8000/image_80.png
# Objects full URL: http://host.docker.internal:8000/image_81.png
# Objects full URL: http://host.docker.internal:8000/image_82.png
# Objects full URL: http://host.docker.internal:8000/image_83.png
# Objects full URL: http://host.docker.internal:8000/image_84.png
# Objects full URL: http://host.docker.internal:8000/image_85.png
# Objects full URL: http://host.docker.internal:8000/image_86.png
# Objects full URL: http://host.docker.internal:8000/image_87.png
# Objects full URL: http://host.docker.internal:8000/image_88.png
# Objects full URL: http://host.docker.internal:8000/image_89.png
# Objects full URL: http://host.docker.internal:8000/image_90.png
# Objects full URL: http://host.docker.internal:8000/image_91.png
# Objects full URL: http://host.docker.internal:8000/image_92.png
# Objects full URL: http://host.docker.internal:8000/image_93.png
# Objects full URL: http://host.docker.internal:8000/image_94.png
# Objects full URL: http://host.docker.internal:8000/image_95.png
# Objects full URL: http://host.docker.internal:8000/image_96.png
# Objects full URL: http://host.docker.internal:8000/image_97.png
# Objects full URL: http://host.docker.internal:8000/image_98.png
# Objects full URL: http://host.docker.internal:8000/image_99.png
# Objects full URL: http://host.docker.internal:8000/image_100.png
# Objects full URL: http://host.docker.internal:8000/image_101.png
# Objects full URL: http://host.docker.internal:8000/image_102.png
# Objects full URL: http://host.docker.internal:8000/image_103.png
# Objects full URL: http://host.docker.internal:8000/image_104.png
# Objects full URL: http://host.docker.internal:8000/image_105.png
# Objects full URL: http://host.docker.internal:8000/image_106.png
# Objects full URL: http://host.docker.internal:8000/image_107.png
# Objects full URL: http://host.docker.internal:8000/image_108.png
# Objects full URL: http://host.docker.internal:8000/image_109.png
# Objects full URL: http://host.docker.internal:8000/image_110.png
# Objects full URL: http://host.docker.internal:8000/image_111.png
# Objects full URL: http://host.docker.internal:8000/image_112.png
# Objects full URL: http://host.docker.internal:8000/image_113.png
# Objects full URL: http://host.docker.internal:8000/image_114.png
# Objects full URL: http://host.docker.internal:8000/image_115.png
# Objects full URL: http://host.docker.internal:8000/image_116.png
# Objects full URL: http://host.docker.internal:8000/image_117.png
# Objects full URL: http://host.docker.internal:8000/image_118.png
# Objects full URL: http://host.docker.internal:8000/image_119.png
# Objects full URL: http://host.docker.internal:8000/image_120.png
# Objects full URL: http://host.docker.internal:8000/image_121.png
# Objects full URL: http://host.docker.internal:8000/image_122.png
# Objects full URL: http://host.docker.internal:8000/image_123.png
# Objects full URL: http://host.docker.internal:8000/image_124.png
# Objects full URL: http://host.docker.internal:8000/image_125.png
# Objects full URL: http://host.docker.internal:8000/image_126.png
# Objects full URL: http://host.docker.internal:8000/image_127.png
# Objects full URL: http://host.docker.internal:8000/image_128.png
# Objects full URL: http://host.docker.internal:8000/image_129.png
# Objects full URL: http://host.docker.internal:8000/image_130.png
# Objects full URL: http://host.docker.internal:8000/image_131.png
# Objects full URL: http://host.docker.internal:8000/image_132.png
# Objects full URL: http://host.docker.internal:8000/image_133.png
# Objects full URL: http://host.docker.internal:8000/image_134.png
# Objects full URL: http://host.docker.internal:8000/image_135.png
# Objects full URL: http://host.docker.internal:8000/image_136.png
# Objects full URL: http://host.docker.internal:8000/image_137.png
# Objects full URL: http://host.docker.internal:8000/image_138.png
# Objects full URL: http://host.docker.internal:8000/image_139.png
# Objects full URL: http://host.docker.internal:8000/image_140.png
# Objects full URL: http://host.docker.internal:8000/image_141.png
# Objects full URL: http://host.docker.internal:8000/image_142.png
# Objects full URL: http://host.docker.internal:8000/image_143.png
# Objects full URL: http://host.docker.internal:8000/image_144.png
# Objects full URL: http://host.docker.internal:8000/image_145.png
# Objects full URL: http://host.docker.internal:8000/image_146.png
# Objects full URL: http://host.docker.internal:8000/image_147.png
# Objects full URL: http://host.docker.internal:8000/image_148.png
# Objects full URL: http://host.docker.internal:8000/image_149.png
# Objects full URL: http://host.docker.internal:8000/image_150.png
# Objects full URL: http://host.docker.internal:8000/image_151.png
# Objects full URL: http://host.docker.internal:8000/image_152.png
# Objects full URL: http://host.docker.internal:8000/image_153.png
# Objects full URL: http://host.docker.internal:8000/image_154.png
# Objects full URL: http://host.docker.internal:8000/image_155.png
# Objects full URL: http://host.docker.internal:8000/image_156.png
# Objects full URL: http://host.docker.internal:8000/image_157.png
# Objects full URL: http://host.docker.internal:8000/image_158.png
# Objects full URL: http://host.docker.internal:8000/image_159.png
# Objects full URL: http://host.docker.internal:8000/image_160.png
# Objects full URL: http://host.docker.internal:8000/image_161.png
# Objects full URL: http://host.docker.internal:8000/image_162.png
# Objects full URL: http://host.docker.internal:8000/image_163.png
# Objects full URL: http://host.docker.internal:8000/image_164.png
# Objects full URL: http://host.docker.internal:8000/image_165.png
# Objects full URL: http://host.docker.internal:8000/image_166.png
# Objects full URL: http://host.docker.internal:8000/image_167.png
# Objects full URL: http://host.docker.internal:8000/image_168.png
# Objects full URL: http://host.docker.internal:8000/image_169.png
# Error getting objects for image http://host.docker.internal:8000/image_169.png: HTTPConnectionPool(host='localhost', port=8764): Read timed out. (read timeout=10)
# Objects full URL: http://host.docker.internal:8000/image_170.png
# Objects full URL: http://host.docker.internal:8000/image_171.png
# Objects full URL: http://host.docker.internal:8000/image_172.png
# Objects full URL: http://host.docker.internal:8000/image_173.png
# Objects full URL: http://host.docker.internal:8000/image_174.png
# Objects full URL: http://host.docker.internal:8000/image_175.png
# Objects full URL: http://host.docker.internal:8000/image_176.png
# Objects full URL: http://host.docker.internal:8000/image_177.png
# Objects full URL: http://host.docker.internal:8000/image_178.png
# Objects full URL: http://host.docker.internal:8000/image_179.png
# Objects full URL: http://host.docker.internal:8000/image_180.png
# Objects full URL: http://host.docker.internal:8000/image_181.png
# Objects full URL: http://host.docker.internal:8000/image_182.png
# Objects full URL: http://host.docker.internal:8000/image_183.png
# Error getting objects for image http://host.docker.internal:8000/image_183.png: HTTPConnectionPool(host='localhost', port=8764): Read timed out. (read timeout=10)
# Objects full URL: http://host.docker.internal:8000/image_184.png
# Objects full URL: http://host.docker.internal:8000/image_185.png
# Objects full URL: http://host.docker.internal:8000/image_186.png
# Objects full URL: http://host.docker.internal:8000/image_187.png
# Objects full URL: http://host.docker.internal:8000/image_188.png
# Objects full URL: http://host.docker.internal:8000/image_189.png
# Objects full URL: http://host.docker.internal:8000/image_190.png
# Objects full URL: http://host.docker.internal:8000/image_191.png
# Objects full URL: http://host.docker.internal:8000/image_192.png
# Objects full URL: http://host.docker.internal:8000/image_193.png
# Objects full URL: http://host.docker.internal:8000/image_194.png
# Objects full URL: http://host.docker.internal:8000/image_195.png
# Objects full URL: http://host.docker.internal:8000/image_196.png
# Objects full URL: http://host.docker.internal:8000/image_197.png
# Objects full URL: http://host.docker.internal:8000/image_198.png
# Objects full URL: http://host.docker.internal:8000/image_199.png
# Objects full URL: http://host.docker.internal:8000/image_200.png
# Objects full URL: http://host.docker.internal:8000/image_201.png
# Objects full URL: http://host.docker.internal:8000/image_202.png
# Objects full URL: http://host.docker.internal:8000/image_203.png
# Objects full URL: http://host.docker.internal:8000/image_204.png
# Objects full URL: http://host.docker.internal:8000/image_205.png
# Objects full URL: http://host.docker.internal:8000/image_206.png
# Objects full URL: http://host.docker.internal:8000/image_207.png
# Objects full URL: http://host.docker.internal:8000/image_208.png
# Objects full URL: http://host.docker.internal:8000/image_209.png
# Objects full URL: http://host.docker.internal:8000/image_210.png
# Objects full URL: http://host.docker.internal:8000/image_211.png
# Objects full URL: http://host.docker.internal:8000/image_212.png
# Objects full URL: http://host.docker.internal:8000/image_213.png
# Objects full URL: http://host.docker.internal:8000/image_214.png
# Objects full URL: http://host.docker.internal:8000/image_215.png
# Objects full URL: http://host.docker.internal:8000/image_216.png
# Objects full URL: http://host.docker.internal:8000/image_217.png
# Objects full URL: http://host.docker.internal:8000/image_218.png
# Objects full URL: http://host.docker.internal:8000/image_219.png
# Objects full URL: http://host.docker.internal:8000/image_220.png
# Objects full URL: http://host.docker.internal:8000/image_221.png
# Objects full URL: http://host.docker.internal:8000/image_222.png
# Objects full URL: http://host.docker.internal:8000/image_223.png
# Objects full URL: http://host.docker.internal:8000/image_224.png
# Objects full URL: http://host.docker.internal:8000/image_225.png
# Objects full URL: http://host.docker.internal:8000/image_226.png
# Objects full URL: http://host.docker.internal:8000/image_227.png
# Objects full URL: http://host.docker.internal:8000/image_228.png
# Objects full URL: http://host.docker.internal:8000/image_229.png
# Objects full URL: http://host.docker.internal:8000/image_230.png
# Objects full URL: http://host.docker.internal:8000/image_231.png
# Objects full URL: http://host.docker.internal:8000/image_232.png
# Objects full URL: http://host.docker.internal:8000/image_233.png
# Objects full URL: http://host.docker.internal:8000/image_234.png
# Objects full URL: http://host.docker.internal:8000/image_235.png
# Objects full URL: http://host.docker.internal:8000/image_236.png
# Objects full URL: http://host.docker.internal:8000/image_237.png
# Objects full URL: http://host.docker.internal:8000/image_238.png
# Objects full URL: http://host.docker.internal:8000/image_239.png
# Objects full URL: http://host.docker.internal:8000/image_240.png
# Objects full URL: http://host.docker.internal:8000/image_241.png
# Objects full URL: http://host.docker.internal:8000/image_242.png
# Objects full URL: http://host.docker.internal:8000/image_243.png
# Objects full URL: http://host.docker.internal:8000/image_244.png
# Objects full URL: http://host.docker.internal:8000/image_245.png
# Objects full URL: http://host.docker.internal:8000/image_246.png
# Objects full URL: http://host.docker.internal:8000/image_247.png
# Objects full URL: http://host.docker.internal:8000/image_248.png
# Objects full URL: http://host.docker.internal:8000/image_249.png
# Objects full URL: http://host.docker.internal:8000/image_250.png
# Objects full URL: http://host.docker.internal:8000/image_251.png
# Objects full URL: http://host.docker.internal:8000/image_252.png
# Objects full URL: http://host.docker.internal:8000/image_253.png
# Objects full URL: http://host.docker.internal:8000/image_254.png
# Objects full URL: http://host.docker.internal:8000/image_255.png
# Objects full URL: http://host.docker.internal:8000/image_256.png
# Objects full URL: http://host.docker.internal:8000/image_257.png
# Objects full URL: http://host.docker.internal:8000/image_258.png
# Objects full URL: http://host.docker.internal:8000/image_259.png
# Objects full URL: http://host.docker.internal:8000/image_260.png
# Objects full URL: http://host.docker.internal:8000/image_261.png
# Objects full URL: http://host.docker.internal:8000/image_262.png
# Objects full URL: http://host.docker.internal:8000/image_263.png
# Objects full URL: http://host.docker.internal:8000/image_264.png
# Objects full URL: http://host.docker.internal:8000/image_265.png
# Objects full URL: http://host.docker.internal:8000/image_266.png
# Objects full URL: http://host.docker.internal:8000/image_267.png
# Objects full URL: http://host.docker.internal:8000/image_268.png
# Objects full URL: http://host.docker.internal:8000/image_269.png
# Objects full URL: http://host.docker.internal:8000/image_270.png
# Objects full URL: http://host.docker.internal:8000/image_271.png
# Objects full URL: http://host.docker.internal:8000/image_272.png
# Objects full URL: http://host.docker.internal:8000/image_273.png
# Objects full URL: http://host.docker.internal:8000/image_274.png
# Objects full URL: http://host.docker.internal:8000/image_275.png
# Objects full URL: http://host.docker.internal:8000/image_276.png
# Objects full URL: http://host.docker.internal:8000/image_277.png
# Objects full URL: http://host.docker.internal:8000/image_278.png
# Objects full URL: http://host.docker.internal:8000/image_279.png
# Objects full URL: http://host.docker.internal:8000/image_280.png
# Objects full URL: http://host.docker.internal:8000/image_281.png
# Objects full URL: http://host.docker.internal:8000/image_282.png
# Objects full URL: http://host.docker.internal:8000/image_283.png
# Objects full URL: http://host.docker.internal:8000/image_284.png
# Objects full URL: http://host.docker.internal:8000/image_285.png
# Objects full URL: http://host.docker.internal:8000/image_286.png
# Objects full URL: http://host.docker.internal:8000/image_287.png
# Objects full URL: http://host.docker.internal:8000/image_288.png
# Objects full URL: http://host.docker.internal:8000/image_289.png
# Objects full URL: http://host.docker.internal:8000/image_290.png
# Objects full URL: http://host.docker.internal:8000/image_291.png
# Objects full URL: http://host.docker.internal:8000/image_292.png
# Objects full URL: http://host.docker.internal:8000/image_293.png
# Objects full URL: http://host.docker.internal:8000/image_294.png
# Objects full URL: http://host.docker.internal:8000/image_295.png
# Objects full URL: http://host.docker.internal:8000/image_296.png
# Objects full URL: http://host.docker.internal:8000/image_297.png
# Objects full URL: http://host.docker.internal:8000/image_298.png
# Objects full URL: http://host.docker.internal:8000/image_299.png
# Objects full URL: http://host.docker.internal:8000/image_300.png
# Objects full URL: http://host.docker.internal:8000/image_301.png
# Objects full URL: http://host.docker.internal:8000/image_302.png
# Objects full URL: http://host.docker.internal:8000/image_303.png
# Objects full URL: http://host.docker.internal:8000/image_304.png
# Objects full URL: http://host.docker.internal:8000/image_305.png
# Objects full URL: http://host.docker.internal:8000/image_306.png
# Objects full URL: http://host.docker.internal:8000/image_307.png
# Objects full URL: http://host.docker.internal:8000/image_308.png
# Objects full URL: http://host.docker.internal:8000/image_309.png
# Objects full URL: http://host.docker.internal:8000/image_310.png
# Objects full URL: http://host.docker.internal:8000/image_311.png
# Objects full URL: http://host.docker.internal:8000/image_312.png
# Objects full URL: http://host.docker.internal:8000/image_313.png
# Objects full URL: http://host.docker.internal:8000/image_314.png
# Objects full URL: http://host.docker.internal:8000/image_315.png
# Objects full URL: http://host.docker.internal:8000/image_316.png
# Objects full URL: http://host.docker.internal:8000/image_317.png
# Objects full URL: http://host.docker.internal:8000/image_318.png
# Objects full URL: http://host.docker.internal:8000/image_319.png
# Objects full URL: http://host.docker.internal:8000/image_320.png
# Objects full URL: http://host.docker.internal:8000/image_321.png
# Objects full URL: http://host.docker.internal:8000/image_322.png
# Objects full URL: http://host.docker.internal:8000/image_323.png
# Objects full URL: http://host.docker.internal:8000/image_324.png
# Objects full URL: http://host.docker.internal:8000/image_325.png
# Objects full URL: http://host.docker.internal:8000/image_326.png
# Objects full URL: http://host.docker.internal:8000/image_327.png
# Objects full URL: http://host.docker.internal:8000/image_328.png
# Objects full URL: http://host.docker.internal:8000/image_329.png
# Objects full URL: http://host.docker.internal:8000/image_330.png
# Objects full URL: http://host.docker.internal:8000/image_331.png
# Objects full URL: http://host.docker.internal:8000/image_332.png
# Objects full URL: http://host.docker.internal:8000/image_333.png
# Objects full URL: http://host.docker.internal:8000/image_334.png
# Objects full URL: http://host.docker.internal:8000/image_335.png
# Objects full URL: http://host.docker.internal:8000/image_336.png
# Objects full URL: http://host.docker.internal:8000/image_337.png
# Objects full URL: http://host.docker.internal:8000/image_338.png
# Objects full URL: http://host.docker.internal:8000/image_339.png
# Objects full URL: http://host.docker.internal:8000/image_340.png
# Objects full URL: http://host.docker.internal:8000/image_341.png
# Objects full URL: http://host.docker.internal:8000/image_342.png
# Objects full URL: http://host.docker.internal:8000/image_343.png
# Objects full URL: http://host.docker.internal:8000/image_344.png
# Objects full URL: http://host.docker.internal:8000/image_345.png
# Objects full URL: http://host.docker.internal:8000/image_346.png
# Objects full URL: http://host.docker.internal:8000/image_347.png
# Objects full URL: http://host.docker.internal:8000/image_348.png
# Objects full URL: http://host.docker.internal:8000/image_349.png
# Objects full URL: http://host.docker.internal:8000/image_350.png
# Objects full URL: http://host.docker.internal:8000/image_351.png
# Objects full URL: http://host.docker.internal:8000/image_352.png
# Objects full URL: http://host.docker.internal:8000/image_353.png
# Objects full URL: http://host.docker.internal:8000/image_354.png
# Objects full URL: http://host.docker.internal:8000/image_355.png
# Objects full URL: http://host.docker.internal:8000/image_356.png
# Objects full URL: http://host.docker.internal:8000/image_357.png
# Objects full URL: http://host.docker.internal:8000/image_358.png
# Objects full URL: http://host.docker.internal:8000/image_359.png
# Objects full URL: http://host.docker.internal:8000/image_360.png
# Objects full URL: http://host.docker.internal:8000/image_361.png
# Objects full URL: http://host.docker.internal:8000/image_362.png
# Objects full URL: http://host.docker.internal:8000/image_363.png
# Objects full URL: http://host.docker.internal:8000/image_364.png
# Objects full URL: http://host.docker.internal:8000/image_365.png
# Objects full URL: http://host.docker.internal:8000/image_366.png
# Objects full URL: http://host.docker.internal:8000/image_367.png
# Objects full URL: http://host.docker.internal:8000/image_368.png
# Objects full URL: http://host.docker.internal:8000/image_369.png
# Objects full URL: http://host.docker.internal:8000/image_370.png
# Objects full URL: http://host.docker.internal:8000/image_371.png
# Objects full URL: http://host.docker.internal:8000/image_372.png
# Objects full URL: http://host.docker.internal:8000/image_373.png
# Objects full URL: http://host.docker.internal:8000/image_374.png
# Objects full URL: http://host.docker.internal:8000/image_375.png
# Objects full URL: http://host.docker.internal:8000/image_376.png
# Objects full URL: http://host.docker.internal:8000/image_377.png
# Objects full URL: http://host.docker.internal:8000/image_378.png
# Objects full URL: http://host.docker.internal:8000/image_379.png
# Objects full URL: http://host.docker.internal:8000/image_380.png
# Objects full URL: http://host.docker.internal:8000/image_381.png
# Objects full URL: http://host.docker.internal:8000/image_382.png
# Objects full URL: http://host.docker.internal:8000/image_383.png
# Objects full URL: http://host.docker.internal:8000/image_384.png
# Objects full URL: http://host.docker.internal:8000/image_385.png
# Objects full URL: http://host.docker.internal:8000/image_386.png
# Objects full URL: http://host.docker.internal:8000/image_387.png
# Objects full URL: http://host.docker.internal:8000/image_388.png
# Objects full URL: http://host.docker.internal:8000/image_389.png
# Objects full URL: http://host.docker.internal:8000/image_390.png
# Objects full URL: http://host.docker.internal:8000/image_391.png
# Objects full URL: http://host.docker.internal:8000/image_392.png
# Objects full URL: http://host.docker.internal:8000/image_393.png
# Objects full URL: http://host.docker.internal:8000/image_394.png
# Objects full URL: http://host.docker.internal:8000/image_395.png
# Objects full URL: http://host.docker.internal:8000/image_396.png
# Objects full URL: http://host.docker.internal:8000/image_397.png
# Objects full URL: http://host.docker.internal:8000/image_398.png
# Objects full URL: http://host.docker.internal:8000/image_399.png
# Objects full URL: http://host.docker.internal:8000/image_400.png
# Objects full URL: http://host.docker.internal:8000/image_401.png
# Objects full URL: http://host.docker.internal:8000/image_402.png
# Objects full URL: http://host.docker.internal:8000/image_403.png
# Objects full URL: http://host.docker.internal:8000/image_404.png
# Objects full URL: http://host.docker.internal:8000/image_405.png
# Objects full URL: http://host.docker.internal:8000/image_406.png
# Objects full URL: http://host.docker.internal:8000/image_407.png
# Objects full URL: http://host.docker.internal:8000/image_408.png
# Objects full URL: http://host.docker.internal:8000/image_409.png
# Objects full URL: http://host.docker.internal:8000/image_410.png
# Objects full URL: http://host.docker.internal:8000/image_411.png
# Objects full URL: http://host.docker.internal:8000/image_412.png
# Objects full URL: http://host.docker.internal:8000/image_413.png
# Objects full URL: http://host.docker.internal:8000/image_414.png
# Objects full URL: http://host.docker.internal:8000/image_415.png
# Objects full URL: http://host.docker.internal:8000/image_416.png
# Objects full URL: http://host.docker.internal:8000/image_417.png
# Objects full URL: http://host.docker.internal:8000/image_418.png
# Objects full URL: http://host.docker.internal:8000/image_419.png
# Objects full URL: http://host.docker.internal:8000/image_420.png
# Objects full URL: http://host.docker.internal:8000/image_421.png
# Objects full URL: http://host.docker.internal:8000/image_422.png
# Objects full URL: http://host.docker.internal:8000/image_423.png
# Objects full URL: http://host.docker.internal:8000/image_424.png
# Objects full URL: http://host.docker.internal:8000/image_425.png
# Objects full URL: http://host.docker.internal:8000/image_426.png
# Objects full URL: http://host.docker.internal:8000/image_427.png
# Objects full URL: http://host.docker.internal:8000/image_428.png
# Objects full URL: http://host.docker.internal:8000/image_429.png
# Objects full URL: http://host.docker.internal:8000/image_430.png
# Objects full URL: http://host.docker.internal:8000/image_431.png
# Objects full URL: http://host.docker.internal:8000/image_432.png
# Objects full URL: http://host.docker.internal:8000/image_433.png
# Objects full URL: http://host.docker.internal:8000/image_434.png
# Objects full URL: http://host.docker.internal:8000/image_435.png
# Objects full URL: http://host.docker.internal:8000/image_436.png
# Objects full URL: http://host.docker.internal:8000/image_437.png
# Objects full URL: http://host.docker.internal:8000/image_438.png
# Objects full URL: http://host.docker.internal:8000/image_439.png
# Objects full URL: http://host.docker.internal:8000/image_440.png
# Objects full URL: http://host.docker.internal:8000/image_441.png
# Objects full URL: http://host.docker.internal:8000/image_442.png
# Objects full URL: http://host.docker.internal:8000/image_443.png
# Objects full URL: http://host.docker.internal:8000/image_444.png
# Objects full URL: http://host.docker.internal:8000/image_445.png
# Objects full URL: http://host.docker.internal:8000/image_446.png
# Objects full URL: http://host.docker.internal:8000/image_447.png
# Objects full URL: http://host.docker.internal:8000/image_448.png
# Objects full URL: http://host.docker.internal:8000/image_449.png
# Objects full URL: http://host.docker.internal:8000/image_450.png
# Objects full URL: http://host.docker.internal:8000/image_451.png
# Objects full URL: http://host.docker.internal:8000/image_452.png
# Objects full URL: http://host.docker.internal:8000/image_453.png
# Objects full URL: http://host.docker.internal:8000/image_454.png
# Objects full URL: http://host.docker.internal:8000/image_455.png
# Objects full URL: http://host.docker.internal:8000/image_456.png
# Objects full URL: http://host.docker.internal:8000/image_457.png
# Objects full URL: http://host.docker.internal:8000/image_458.png
# Objects full URL: http://host.docker.internal:8000/image_459.png
# Objects full URL: http://host.docker.internal:8000/image_460.png
# Objects full URL: http://host.docker.internal:8000/image_461.png
# Objects full URL: http://host.docker.internal:8000/image_462.png
# Objects full URL: http://host.docker.internal:8000/image_463.png
# Objects full URL: http://host.docker.internal:8000/image_464.png
# Objects full URL: http://host.docker.internal:8000/image_465.png
# Objects full URL: http://host.docker.internal:8000/image_466.png
# Objects full URL: http://host.docker.internal:8000/image_467.png
# Objects full URL: http://host.docker.internal:8000/image_468.png
# Objects full URL: http://host.docker.internal:8000/image_469.png
# Objects full URL: http://host.docker.internal:8000/image_470.png
# Objects full URL: http://host.docker.internal:8000/image_471.png
# Objects full URL: http://host.docker.internal:8000/image_472.png
# Objects full URL: http://host.docker.internal:8000/image_473.png
# Objects full URL: http://host.docker.internal:8000/image_474.png
# Objects full URL: http://host.docker.internal:8000/image_475.png
# Objects full URL: http://host.docker.internal:8000/image_476.png
# Objects full URL: http://host.docker.internal:8000/image_477.png
# Objects full URL: http://host.docker.internal:8000/image_478.png
# Objects full URL: http://host.docker.internal:8000/image_479.png
# Objects full URL: http://host.docker.internal:8000/image_480.png
# Objects full URL: http://host.docker.internal:8000/image_481.png
# Objects full URL: http://host.docker.internal:8000/image_482.png
# Objects full URL: http://host.docker.internal:8000/image_483.png
# Objects full URL: http://host.docker.internal:8000/image_484.png
# Objects full URL: http://host.docker.internal:8000/image_485.png
# Objects full URL: http://host.docker.internal:8000/image_486.png
# Objects full URL: http://host.docker.internal:8000/image_487.png
# Objects full URL: http://host.docker.internal:8000/image_488.png
# Objects full URL: http://host.docker.internal:8000/image_489.png
# Objects full URL: http://host.docker.internal:8000/image_490.png
# Objects full URL: http://host.docker.internal:8000/image_491.png
# Objects full URL: http://host.docker.internal:8000/image_492.png
# Objects full URL: http://host.docker.internal:8000/image_493.png
# Objects full URL: http://host.docker.internal:8000/image_494.png
# Objects full URL: http://host.docker.internal:8000/image_495.png
# Objects full URL: http://host.docker.internal:8000/image_496.png
# Objects full URL: http://host.docker.internal:8000/image_497.png
# Objects full URL: http://host.docker.internal:8000/image_498.png
# Objects full URL: http://host.docker.internal:8000/image_499.png
# Objects full URL: http://host.docker.internal:8000/image_500.png
# Objects full URL: http://host.docker.internal:8000/image_501.png
# Objects full URL: http://host.docker.internal:8000/image_502.png
# Objects full URL: http://host.docker.internal:8000/image_503.png
# Objects full URL: http://host.docker.internal:8000/image_504.png
# Objects full URL: http://host.docker.internal:8000/image_505.png
# Objects full URL: http://host.docker.internal:8000/image_506.png
# Objects full URL: http://host.docker.internal:8000/image_507.png
# Objects full URL: http://host.docker.internal:8000/image_508.png
# Objects full URL: http://host.docker.internal:8000/image_509.png
# Objects full URL: http://host.docker.internal:8000/image_510.png
# Objects full URL: http://host.docker.internal:8000/image_511.png
# Objects full URL: http://host.docker.internal:8000/image_512.png
# Objects full URL: http://host.docker.internal:8000/image_513.png
# Objects full URL: http://host.docker.internal:8000/image_514.png
# Objects full URL: http://host.docker.internal:8000/image_515.png
# Objects full URL: http://host.docker.internal:8000/image_516.png
# Objects full URL: http://host.docker.internal:8000/image_517.png
# Objects full URL: http://host.docker.internal:8000/image_518.png
# Objects full URL: http://host.docker.internal:8000/image_519.png
# Objects full URL: http://host.docker.internal:8000/image_520.png
# Objects full URL: http://host.docker.internal:8000/image_521.png
# Objects full URL: http://host.docker.internal:8000/image_522.png
# Objects full URL: http://host.docker.internal:8000/image_523.png
# Objects full URL: http://host.docker.internal:8000/image_524.png
# Objects full URL: http://host.docker.internal:8000/image_525.png
# Objects full URL: http://host.docker.internal:8000/image_526.png
# Objects full URL: http://host.docker.internal:8000/image_527.png
# Objects full URL: http://host.docker.internal:8000/image_528.png
# Objects full URL: http://host.docker.internal:8000/image_529.png
# Objects full URL: http://host.docker.internal:8000/image_530.png
# Objects full URL: http://host.docker.internal:8000/image_531.png
# Objects full URL: http://host.docker.internal:8000/image_532.png
# Objects full URL: http://host.docker.internal:8000/image_533.png
# Objects full URL: http://host.docker.internal:8000/image_534.png
# Objects full URL: http://host.docker.internal:8000/image_535.png
# Objects full URL: http://host.docker.internal:8000/image_536.png
# Objects full URL: http://host.docker.internal:8000/image_537.png
# Objects full URL: http://host.docker.internal:8000/image_538.png
# Objects full URL: http://host.docker.internal:8000/image_539.png
# Objects full URL: http://host.docker.internal:8000/image_540.png
# Objects full URL: http://host.docker.internal:8000/image_541.png
# Objects full URL: http://host.docker.internal:8000/image_542.png
# Objects full URL: http://host.docker.internal:8000/image_543.png
# Objects full URL: http://host.docker.internal:8000/image_544.png
# Objects full URL: http://host.docker.internal:8000/image_545.png
# Objects full URL: http://host.docker.internal:8000/image_546.png
# Objects full URL: http://host.docker.internal:8000/image_547.png
# Objects full URL: http://host.docker.internal:8000/image_548.png
# Objects full URL: http://host.docker.internal:8000/image_549.png
# Objects full URL: http://host.docker.internal:8000/image_550.png
# Objects full URL: http://host.docker.internal:8000/image_551.png
# Objects full URL: http://host.docker.internal:8000/image_552.png
# Objects full URL: http://host.docker.internal:8000/image_553.png
# Objects full URL: http://host.docker.internal:8000/image_554.png
# Objects full URL: http://host.docker.internal:8000/image_555.png
# Objects full URL: http://host.docker.internal:8000/image_556.png
# Objects full URL: http://host.docker.internal:8000/image_557.png
# Objects full URL: http://host.docker.internal:8000/image_558.png
# Objects full URL: http://host.docker.internal:8000/image_559.png
# Objects full URL: http://host.docker.internal:8000/image_560.png
# Objects full URL: http://host.docker.internal:8000/image_561.png
# Objects full URL: http://host.docker.internal:8000/image_562.png
# Objects full URL: http://host.docker.internal:8000/image_563.png
# Objects full URL: http://host.docker.internal:8000/image_564.png
# Objects full URL: http://host.docker.internal:8000/image_565.png
# Objects full URL: http://host.docker.internal:8000/image_566.png
# Objects full URL: http://host.docker.internal:8000/image_567.png
# Objects full URL: http://host.docker.internal:8000/image_568.png
# Objects full URL: http://host.docker.internal:8000/image_569.png
# Objects full URL: http://host.docker.internal:8000/image_570.png
# Objects full URL: http://host.docker.internal:8000/image_571.png
# Objects full URL: http://host.docker.internal:8000/image_572.png
# Objects full URL: http://host.docker.internal:8000/image_573.png
# Objects full URL: http://host.docker.internal:8000/image_574.png
# Objects full URL: http://host.docker.internal:8000/image_575.png
# Objects full URL: http://host.docker.internal:8000/image_576.png
# Objects full URL: http://host.docker.internal:8000/image_577.png
# Objects full URL: http://host.docker.internal:8000/image_578.png
# Objects full URL: http://host.docker.internal:8000/image_579.png
# Objects full URL: http://host.docker.internal:8000/image_580.png
# Objects full URL: http://host.docker.internal:8000/image_581.png
# Objects full URL: http://host.docker.internal:8000/image_582.png
# Objects full URL: http://host.docker.internal:8000/image_583.png
# Objects full URL: http://host.docker.internal:8000/image_584.png
# Objects full URL: http://host.docker.internal:8000/image_585.png
# Objects full URL: http://host.docker.internal:8000/image_586.png
# Objects full URL: http://host.docker.internal:8000/image_587.png
# Objects full URL: http://host.docker.internal:8000/image_588.png
# Objects full URL: http://host.docker.internal:8000/image_589.png
# Objects full URL: http://host.docker.internal:8000/image_590.png
# Objects full URL: http://host.docker.internal:8000/image_591.png
# Objects full URL: http://host.docker.internal:8000/image_592.png
# Objects full URL: http://host.docker.internal:8000/image_593.png
# Objects full URL: http://host.docker.internal:8000/image_594.png
# Objects full URL: http://host.docker.internal:8000/image_595.png
# Objects full URL: http://host.docker.internal:8000/image_596.png
# Objects full URL: http://host.docker.internal:8000/image_597.png
# Objects full URL: http://host.docker.internal:8000/image_598.png
# Objects full URL: http://host.docker.internal:8000/image_599.png
# Objects full URL: http://host.docker.internal:8000/image_600.png
# Objects full URL: http://host.docker.internal:8000/image_601.png
# Objects full URL: http://host.docker.internal:8000/image_602.png
# Objects full URL: http://host.docker.internal:8000/image_603.png
# Objects full URL: http://host.docker.internal:8000/image_604.png
# Objects full URL: http://host.docker.internal:8000/image_605.png
# Objects full URL: http://host.docker.internal:8000/image_606.png
# Objects full URL: http://host.docker.internal:8000/image_607.png
# Objects full URL: http://host.docker.internal:8000/image_608.png
# Objects full URL: http://host.docker.internal:8000/image_609.png
# Objects full URL: http://host.docker.internal:8000/image_610.png
# Objects full URL: http://host.docker.internal:8000/image_611.png
# Objects full URL: http://host.docker.internal:8000/image_612.png
# Objects full URL: http://host.docker.internal:8000/image_613.png
# Objects full URL: http://host.docker.internal:8000/image_614.png
# Objects full URL: http://host.docker.internal:8000/image_615.png
# Objects full URL: http://host.docker.internal:8000/image_616.png
# Objects full URL: http://host.docker.internal:8000/image_617.png
# Objects full URL: http://host.docker.internal:8000/image_618.png
# Objects full URL: http://host.docker.internal:8000/image_619.png
# Objects full URL: http://host.docker.internal:8000/image_620.png
# Objects full URL: http://host.docker.internal:8000/image_621.png
# Objects full URL: http://host.docker.internal:8000/image_622.png
# Objects full URL: http://host.docker.internal:8000/image_623.png
# Objects full URL: http://host.docker.internal:8000/image_624.png
# Objects full URL: http://host.docker.internal:8000/image_625.png
# Objects full URL: http://host.docker.internal:8000/image_626.png
# Objects full URL: http://host.docker.internal:8000/image_627.png
# Objects full URL: http://host.docker.internal:8000/image_628.png
# Objects full URL: http://host.docker.internal:8000/image_629.png
# Objects full URL: http://host.docker.internal:8000/image_630.png
# Objects full URL: http://host.docker.internal:8000/image_631.png
# Objects full URL: http://host.docker.internal:8000/image_632.png
# Objects full URL: http://host.docker.internal:8000/image_633.png
# Objects full URL: http://host.docker.internal:8000/image_634.png
# Objects full URL: http://host.docker.internal:8000/image_635.png
# Error getting objects for image http://host.docker.internal:8000/image_635.png: HTTPConnectionPool(host='localhost', port=8764): Read timed out. (read timeout=10)
# Objects full URL: http://host.docker.internal:8000/image_636.png
# Objects full URL: http://host.docker.internal:8000/image_637.png
# Objects full URL: http://host.docker.internal:8000/image_638.png
# Objects full URL: http://host.docker.internal:8000/image_639.png
# Objects full URL: http://host.docker.internal:8000/image_640.png
# Objects full URL: http://host.docker.internal:8000/image_641.png
# Objects full URL: http://host.docker.internal:8000/image_642.png
# Objects full URL: http://host.docker.internal:8000/image_643.png
# Objects full URL: http://host.docker.internal:8000/image_644.png
# Objects full URL: http://host.docker.internal:8000/image_645.png
# Objects full URL: http://host.docker.internal:8000/image_646.png
# Objects full URL: http://host.docker.internal:8000/image_647.png
# Objects full URL: http://host.docker.internal:8000/image_648.png
# Objects full URL: http://host.docker.internal:8000/image_649.png
# Objects full URL: http://host.docker.internal:8000/image_650.png
# Objects full URL: http://host.docker.internal:8000/image_651.png
# Objects full URL: http://host.docker.internal:8000/image_652.png
# Objects full URL: http://host.docker.internal:8000/image_653.png
# Objects full URL: http://host.docker.internal:8000/image_654.png
# Objects full URL: http://host.docker.internal:8000/image_655.png
# Objects full URL: http://host.docker.internal:8000/image_656.png
# Objects full URL: http://host.docker.internal:8000/image_657.png
# Objects full URL: http://host.docker.internal:8000/image_658.png
# Objects full URL: http://host.docker.internal:8000/image_659.png
# Objects full URL: http://host.docker.internal:8000/image_660.png
# Objects full URL: http://host.docker.internal:8000/image_661.png
# Objects full URL: http://host.docker.internal:8000/image_662.png
# Objects full URL: http://host.docker.internal:8000/image_663.png
# Objects full URL: http://host.docker.internal:8000/image_664.png
# Objects full URL: http://host.docker.internal:8000/image_665.png
# Objects full URL: http://host.docker.internal:8000/image_666.png
# Objects full URL: http://host.docker.internal:8000/image_667.png
# Objects full URL: http://host.docker.internal:8000/image_668.png
# Objects full URL: http://host.docker.internal:8000/image_669.png
# Objects full URL: http://host.docker.internal:8000/image_670.png
# Objects full URL: http://host.docker.internal:8000/image_671.png
# Objects full URL: http://host.docker.internal:8000/image_672.png
# Objects full URL: http://host.docker.internal:8000/image_673.png
# Objects full URL: http://host.docker.internal:8000/image_674.png
# Objects full URL: http://host.docker.internal:8000/image_675.png
# Objects full URL: http://host.docker.internal:8000/image_676.png
# Objects full URL: http://host.docker.internal:8000/image_677.png
# Objects full URL: http://host.docker.internal:8000/image_678.png
# Objects full URL: http://host.docker.internal:8000/image_679.png
# Objects full URL: http://host.docker.internal:8000/image_680.png
# Objects full URL: http://host.docker.internal:8000/image_681.png
# Objects full URL: http://host.docker.internal:8000/image_682.png
# Objects full URL: http://host.docker.internal:8000/image_683.png
# Objects full URL: http://host.docker.internal:8000/image_684.png
# Objects full URL: http://host.docker.internal:8000/image_685.png
# Objects full URL: http://host.docker.internal:8000/image_686.png
# Objects full URL: http://host.docker.internal:8000/image_687.png
# Objects full URL: http://host.docker.internal:8000/image_688.png
# Objects full URL: http://host.docker.internal:8000/image_689.png
# Objects full URL: http://host.docker.internal:8000/image_690.png
# Objects full URL: http://host.docker.internal:8000/image_691.png
# Objects full URL: http://host.docker.internal:8000/image_692.png
# Objects full URL: http://host.docker.internal:8000/image_693.png
# Objects full URL: http://host.docker.internal:8000/image_694.png
# Objects full URL: http://host.docker.internal:8000/image_695.png
# Objects full URL: http://host.docker.internal:8000/image_696.png
# Objects full URL: http://host.docker.internal:8000/image_697.png
# Objects full URL: http://host.docker.internal:8000/image_698.png
# Objects full URL: http://host.docker.internal:8000/image_699.png
# Objects full URL: http://host.docker.internal:8000/image_700.png
# Objects full URL: http://host.docker.internal:8000/image_701.png
# Objects full URL: http://host.docker.internal:8000/image_702.png
# Objects full URL: http://host.docker.internal:8000/image_703.png
# Objects full URL: http://host.docker.internal:8000/image_704.png
# Objects full URL: http://host.docker.internal:8000/image_705.png
# Objects full URL: http://host.docker.internal:8000/image_706.png
# Objects full URL: http://host.docker.internal:8000/image_707.png
# Objects full URL: http://host.docker.internal:8000/image_708.png
# Objects full URL: http://host.docker.internal:8000/image_709.png
# Objects full URL: http://host.docker.internal:8000/image_710.png
# Objects full URL: http://host.docker.internal:8000/image_711.png
# Objects full URL: http://host.docker.internal:8000/image_712.png
# Objects full URL: http://host.docker.internal:8000/image_713.png
# Objects full URL: http://host.docker.internal:8000/image_714.png
# Objects full URL: http://host.docker.internal:8000/image_715.png
# Objects full URL: http://host.docker.internal:8000/image_716.png
# Objects full URL: http://host.docker.internal:8000/image_717.png
# Objects full URL: http://host.docker.internal:8000/image_718.png
# Objects full URL: http://host.docker.internal:8000/image_719.png
# Objects full URL: http://host.docker.internal:8000/image_720.png
# Objects full URL: http://host.docker.internal:8000/image_721.png
# Objects full URL: http://host.docker.internal:8000/image_722.png
# Objects full URL: http://host.docker.internal:8000/image_723.png
# Objects full URL: http://host.docker.internal:8000/image_724.png
# Objects full URL: http://host.docker.internal:8000/image_725.png
# Objects full URL: http://host.docker.internal:8000/image_726.png
# Objects full URL: http://host.docker.internal:8000/image_727.png
# Objects full URL: http://host.docker.internal:8000/image_728.png
# Objects full URL: http://host.docker.internal:8000/image_729.png
# Objects full URL: http://host.docker.internal:8000/image_730.png
# Objects full URL: http://host.docker.internal:8000/image_731.png
# ...
# Objects full URL: http://host.docker.internal:8000/image_9492.png
# Objects full URL: http://host.docker.internal:8000/image_9493.png
# Objects full URL: http://host.docker.internal:8000/image_9494.png
# Objects full URL: http://host.docker.internal:8000/image_9495.png
# Objects full URL: http://host.docker.internal:8000/image_9496.png
# Objects full URL: http://host.docker.internal:8000/image_9497.png
# Objects full URL: http://host.docker.internal:8000/image_9498.png
# Objects full URL: http://host.docker.internal:8000/image_9499.png
# Objects full URL: http://host.docker.internal:8000/image_9500.png
# Objects full URL: http://host.docker.internal:8000/image_9501.png
# Objects full URL: http://host.docker.internal:8000/image_9502.png
# Objects full URL: http://host.docker.internal:8000/image_9503.png
# Objects full URL: http://host.docker.internal:8000/image_9504.png
# Objects full URL: http://host.docker.internal:8000/image_9505.png
# Objects full URL: http://host.docker.internal:8000/image_9506.png
# Objects full URL: http://host.docker.internal:8000/image_9507.png
# Objects full URL: http://host.docker.internal:8000/image_9508.png
# Objects full URL: http://host.docker.internal:8000/image_9509.png
# Objects full URL: http://host.docker.internal:8000/image_9510.png
# Objects full URL: http://host.docker.internal:8000/image_9511.png
# Objects full URL: http://host.docker.internal:8000/image_9512.png
# Objects full URL: http://host.docker.internal:8000/image_9513.png
# Objects full URL: http://host.docker.internal:8000/image_9514.png
# Objects full URL: http://host.docker.internal:8000/image_9515.png
# Objects full URL: http://host.docker.internal:8000/image_9516.png
# Objects full URL: http://host.docker.internal:8000/image_9517.png
# Objects full URL: http://host.docker.internal:8000/image_9518.png
# Objects full URL: http://host.docker.internal:8000/image_9519.png
# Objects full URL: http://host.docker.internal:8000/image_9520.png
# Objects full URL: http://host.docker.internal:8000/image_9521.png
# Objects full URL: http://host.docker.internal:8000/image_9522.png
# Objects full URL: http://host.docker.internal:8000/image_9523.png
# Objects full URL: http://host.docker.internal:8000/image_9524.png
# Objects full URL: http://host.docker.internal:8000/image_9525.png
# Objects full URL: http://host.docker.internal:8000/image_9526.png
# Objects full URL: http://host.docker.internal:8000/image_9527.png
# Objects full URL: http://host.docker.internal:8000/image_9528.png
# Objects full URL: http://host.docker.internal:8000/image_9529.png
# Objects full URL: http://host.docker.internal:8000/image_9530.png
# Objects full URL: http://host.docker.internal:8000/image_9531.png
# Objects full URL: http://host.docker.internal:8000/image_9532.png
# Objects full URL: http://host.docker.internal:8000/image_9533.png
# Objects full URL: http://host.docker.internal:8000/image_9534.png
# Objects full URL: http://host.docker.internal:8000/image_9535.png
# Objects full URL: http://host.docker.internal:8000/image_9536.png
# Objects full URL: http://host.docker.internal:8000/image_9537.png
# Objects full URL: http://host.docker.internal:8000/image_9538.png
# Objects full URL: http://host.docker.internal:8000/image_9539.png
# Objects full URL: http://host.docker.internal:8000/image_9540.png
# Objects full URL: http://host.docker.internal:8000/image_9541.png
# Objects full URL: http://host.docker.internal:8000/image_9542.png
# Objects full URL: http://host.docker.internal:8000/image_9543.png
# Objects full URL: http://host.docker.internal:8000/image_9544.png
# Objects full URL: http://host.docker.internal:8000/image_9545.png
# Objects full URL: http://host.docker.internal:8000/image_9546.png
# Objects full URL: http://host.docker.internal:8000/image_9547.png
# Objects full URL: http://host.docker.internal:8000/image_9548.png
# Objects full URL: http://host.docker.internal:8000/image_9549.png
# Objects full URL: http://host.docker.internal:8000/image_9550.png
# Objects full URL: http://host.docker.internal:8000/image_9551.png
# Objects full URL: http://host.docker.internal:8000/image_9552.png
# Objects full URL: http://host.docker.internal:8000/image_9553.png
# Objects full URL: http://host.docker.internal:8000/image_9554.png
# Objects full URL: http://host.docker.internal:8000/image_9555.png
# Objects full URL: http://host.docker.internal:8000/image_9556.png
# Objects full URL: http://host.docker.internal:8000/image_9557.png
# Objects full URL: http://host.docker.internal:8000/image_9558.png
# Objects full URL: http://host.docker.internal:8000/image_9559.png
# Objects full URL: http://host.docker.internal:8000/image_9560.png
# Objects full URL: http://host.docker.internal:8000/image_9561.png
# Objects full URL: http://host.docker.internal:8000/image_9562.png
# Objects full URL: http://host.docker.internal:8000/image_9563.png
# Objects full URL: http://host.docker.internal:8000/image_9564.png
# Objects full URL: http://host.docker.internal:8000/image_9565.png
# Objects full URL: http://host.docker.internal:8000/image_9566.png
# Objects full URL: http://host.docker.internal:8000/image_9567.png
# Objects full URL: http://host.docker.internal:8000/image_9568.png
# Objects full URL: http://host.docker.internal:8000/image_9569.png
# Objects full URL: http://host.docker.internal:8000/image_9570.png
# Objects full URL: http://host.docker.internal:8000/image_9571.png
# Objects full URL: http://host.docker.internal:8000/image_9572.png
# Objects full URL: http://host.docker.internal:8000/image_9573.png
# Objects full URL: http://host.docker.internal:8000/image_9574.png
# Objects full URL: http://host.docker.internal:8000/image_9575.png
# Objects full URL: http://host.docker.internal:8000/image_9576.png
# Objects full URL: http://host.docker.internal:8000/image_9577.png
# Objects full URL: http://host.docker.internal:8000/image_9578.png
# Objects full URL: http://host.docker.internal:8000/image_9579.png
# Objects full URL: http://host.docker.internal:8000/image_9580.png
# Objects full URL: http://host.docker.internal:8000/image_9581.png
# Objects full URL: http://host.docker.internal:8000/image_9582.png
# Objects full URL: http://host.docker.internal:8000/image_9583.png
# Objects full URL: http://host.docker.internal:8000/image_9584.png
# Objects full URL: http://host.docker.internal:8000/image_9585.png
# Objects full URL: http://host.docker.internal:8000/image_9586.png
# Objects full URL: http://host.docker.internal:8000/image_9587.png
# Objects full URL: http://host.docker.internal:8000/image_9588.png
# Objects full URL: http://host.docker.internal:8000/image_9589.png
# Objects full URL: http://host.docker.internal:8000/image_9590.png
# Objects full URL: http://host.docker.internal:8000/image_9591.png
# Objects full URL: http://host.docker.internal:8000/image_9592.png
# Objects full URL: http://host.docker.internal:8000/image_9593.png
# Objects full URL: http://host.docker.internal:8000/image_9594.png
# Objects full URL: http://host.docker.internal:8000/image_9595.png
# Objects full URL: http://host.docker.internal:8000/image_9596.png
# Objects full URL: http://host.docker.internal:8000/image_9597.png
# Objects full URL: http://host.docker.internal:8000/image_9598.png
# Objects full URL: http://host.docker.internal:8000/image_9599.png
# Objects full URL: http://host.docker.internal:8000/image_9600.png
# Objects full URL: http://host.docker.internal:8000/image_9601.png
# Objects full URL: http://host.docker.internal:8000/image_9602.png
# Objects full URL: http://host.docker.internal:8000/image_9603.png
# Objects full URL: http://host.docker.internal:8000/image_9604.png
# Objects full URL: http://host.docker.internal:8000/image_9605.png
# Objects full URL: http://host.docker.internal:8000/image_9606.png
# Objects full URL: http://host.docker.internal:8000/image_9607.png
# Objects full URL: http://host.docker.internal:8000/image_9608.png
# Objects full URL: http://host.docker.internal:8000/image_9609.png
# Objects full URL: http://host.docker.internal:8000/image_9610.png
# Objects full URL: http://host.docker.internal:8000/image_9611.png
# Objects full URL: http://host.docker.internal:8000/image_9612.png
# Objects full URL: http://host.docker.internal:8000/image_9613.png
# Objects full URL: http://host.docker.internal:8000/image_9614.png
# Objects full URL: http://host.docker.internal:8000/image_9615.png
# Objects full URL: http://host.docker.internal:8000/image_9616.png
# Objects full URL: http://host.docker.internal:8000/image_9617.png
# Objects full URL: http://host.docker.internal:8000/image_9618.png
# Objects full URL: http://host.docker.internal:8000/image_9619.png
# Objects full URL: http://host.docker.internal:8000/image_9620.png
# Objects full URL: http://host.docker.internal:8000/image_9621.png
# Error getting objects for image http://host.docker.internal:8000/image_9621.png: HTTPConnectionPool(host='localhost', port=8764): Read timed out. (read timeout=10)
# Objects full URL: http://host.docker.internal:8000/image_9622.png
# Objects full URL: http://host.docker.internal:8000/image_9623.png
# Objects full URL: http://host.docker.internal:8000/image_9624.png
# Objects full URL: http://host.docker.internal:8000/image_9625.png
# Objects full URL: http://host.docker.internal:8000/image_9626.png
# Objects full URL: http://host.docker.internal:8000/image_9627.png
# Objects full URL: http://host.docker.internal:8000/image_9628.png
# Objects full URL: http://host.docker.internal:8000/image_9629.png
# Objects full URL: http://host.docker.internal:8000/image_9630.png
# Objects full URL: http://host.docker.internal:8000/image_9631.png
# Objects full URL: http://host.docker.internal:8000/image_9632.png
# Objects full URL: http://host.docker.internal:8000/image_9633.png
# Objects full URL: http://host.docker.internal:8000/image_9634.png
# Objects full URL: http://host.docker.internal:8000/image_9635.png
# Objects full URL: http://host.docker.internal:8000/image_9636.png
# Objects full URL: http://host.docker.internal:8000/image_9637.png
# Objects full URL: http://host.docker.internal:8000/image_9638.png
# Objects full URL: http://host.docker.internal:8000/image_9639.png
# Objects full URL: http://host.docker.internal:8000/image_9640.png
# Objects full URL: http://host.docker.internal:8000/image_9641.png
# Objects full URL: http://host.docker.internal:8000/image_9642.png
# Objects full URL: http://host.docker.internal:8000/image_9643.png
# Objects full URL: http://host.docker.internal:8000/image_9644.png
# Objects full URL: http://host.docker.internal:8000/image_9645.png
# Objects full URL: http://host.docker.internal:8000/image_9646.png
# Objects full URL: http://host.docker.internal:8000/image_9647.png
# Objects full URL: http://host.docker.internal:8000/image_9648.png
# Objects full URL: http://host.docker.internal:8000/image_9649.png
# Objects full URL: http://host.docker.internal:8000/image_9650.png
# Objects full URL: http://host.docker.internal:8000/image_9651.png
# Objects full URL: http://host.docker.internal:8000/image_9652.png
# Objects full URL: http://host.docker.internal:8000/image_9653.png
# Objects full URL: http://host.docker.internal:8000/image_9654.png
# Objects full URL: http://host.docker.internal:8000/image_9655.png
# Objects full URL: http://host.docker.internal:8000/image_9656.png
# Objects full URL: http://host.docker.internal:8000/image_9657.png
# Objects full URL: http://host.docker.internal:8000/image_9658.png
# Objects full URL: http://host.docker.internal:8000/image_9659.png
# Objects full URL: http://host.docker.internal:8000/image_9660.png
# Objects full URL: http://host.docker.internal:8000/image_9661.png
# Objects full URL: http://host.docker.internal:8000/image_9662.png
# Objects full URL: http://host.docker.internal:8000/image_9663.png
# Objects full URL: http://host.docker.internal:8000/image_9664.png
# Objects full URL: http://host.docker.internal:8000/image_9665.png
# Objects full URL: http://host.docker.internal:8000/image_9666.png
# Objects full URL: http://host.docker.internal:8000/image_9667.png
# Objects full URL: http://host.docker.internal:8000/image_9668.png
# Objects full URL: http://host.docker.internal:8000/image_9669.png
# Objects full URL: http://host.docker.internal:8000/image_9670.png
# Objects full URL: http://host.docker.internal:8000/image_9671.png
# Objects full URL: http://host.docker.internal:8000/image_9672.png
# Objects full URL: http://host.docker.internal:8000/image_9673.png
# Objects full URL: http://host.docker.internal:8000/image_9674.png
# Objects full URL: http://host.docker.internal:8000/image_9675.png
# Objects full URL: http://host.docker.internal:8000/image_9676.png
# Objects full URL: http://host.docker.internal:8000/image_9677.png
# Objects full URL: http://host.docker.internal:8000/image_9678.png
# Objects full URL: http://host.docker.internal:8000/image_9679.png
# Objects full URL: http://host.docker.internal:8000/image_9680.png
# Objects full URL: http://host.docker.internal:8000/image_9681.png
# Objects full URL: http://host.docker.internal:8000/image_9682.png
# Objects full URL: http://host.docker.internal:8000/image_9683.png
# Objects full URL: http://host.docker.internal:8000/image_9684.png
# Objects full URL: http://host.docker.internal:8000/image_9685.png
# Objects full URL: http://host.docker.internal:8000/image_9686.png
# Objects full URL: http://host.docker.internal:8000/image_9687.png
# Objects full URL: http://host.docker.internal:8000/image_9688.png
# Objects full URL: http://host.docker.internal:8000/image_9689.png
# Objects full URL: http://host.docker.internal:8000/image_9690.png
# Objects full URL: http://host.docker.internal:8000/image_9691.png
# Objects full URL: http://host.docker.internal:8000/image_9692.png
# Objects full URL: http://host.docker.internal:8000/image_9693.png
# Objects full URL: http://host.docker.internal:8000/image_9694.png
# Objects full URL: http://host.docker.internal:8000/image_9695.png
# Objects full URL: http://host.docker.internal:8000/image_9696.png
# Objects full URL: http://host.docker.internal:8000/image_9697.png
# Objects full URL: http://host.docker.internal:8000/image_9698.png
# Objects full URL: http://host.docker.internal:8000/image_9699.png
# Objects full URL: http://host.docker.internal:8000/image_9700.png
# Objects full URL: http://host.docker.internal:8000/image_9701.png
# Objects full URL: http://host.docker.internal:8000/image_9702.png
# Objects full URL: http://host.docker.internal:8000/image_9703.png
# Objects full URL: http://host.docker.internal:8000/image_9704.png
# Objects full URL: http://host.docker.internal:8000/image_9705.png
# Objects full URL: http://host.docker.internal:8000/image_9706.png
# Objects full URL: http://host.docker.internal:8000/image_9707.png
# Objects full URL: http://host.docker.internal:8000/image_9708.png
# Objects full URL: http://host.docker.internal:8000/image_9709.png
# Objects full URL: http://host.docker.internal:8000/image_9710.png
# Objects full URL: http://host.docker.internal:8000/image_9711.png
# Objects full URL: http://host.docker.internal:8000/image_9712.png
# Objects full URL: http://host.docker.internal:8000/image_9713.png
# Objects full URL: http://host.docker.internal:8000/image_9714.png
# Objects full URL: http://host.docker.internal:8000/image_9715.png
# Objects full URL: http://host.docker.internal:8000/image_9716.png
# Objects full URL: http://host.docker.internal:8000/image_9717.png
# Objects full URL: http://host.docker.internal:8000/image_9718.png
# Objects full URL: http://host.docker.internal:8000/image_9719.png
# Objects full URL: http://host.docker.internal:8000/image_9720.png
# Objects full URL: http://host.docker.internal:8000/image_9721.png
# Objects full URL: http://host.docker.internal:8000/image_9722.png
# Objects full URL: http://host.docker.internal:8000/image_9723.png
# Objects full URL: http://host.docker.internal:8000/image_9724.png
# Objects full URL: http://host.docker.internal:8000/image_9725.png
# Objects full URL: http://host.docker.internal:8000/image_9726.png
# Objects full URL: http://host.docker.internal:8000/image_9727.png
# Objects full URL: http://host.docker.internal:8000/image_9728.png
# Objects full URL: http://host.docker.internal:8000/image_9729.png
# Objects full URL: http://host.docker.internal:8000/image_9730.png

# %%
numbers = [
    183, 635, 933, 1004, 1396, 2005,
    2543, 3353, 4455, 4501, 5162, 5773,
    5987, 6042, 6262, 6404, 7036, 7081,
    7445, 8041, 8094, 8353, 8371, 8525, 8792,
    9300, 9303, 9621
]
for num in numbers:
    df2.loc[num, "objects"] = get_objects(df2.loc[num, "IMG_LOC"])
# Out:
# Objects full URL: http://host.docker.internal:8000/image_183.png
# Objects full URL: http://host.docker.internal:8000/image_635.png
# Objects full URL: http://host.docker.internal:8000/image_933.png
# Objects full URL: http://host.docker.internal:8000/image_1004.png
# Objects full URL: http://host.docker.internal:8000/image_1396.png
# Objects full URL: http://host.docker.internal:8000/image_2005.png
# Objects full URL: http://host.docker.internal:8000/image_2543.png
# Objects full URL: http://host.docker.internal:8000/image_3353.png
# Objects full URL: http://host.docker.internal:8000/image_4455.png
# Objects full URL: http://host.docker.internal:8000/image_4501.png
# Objects full URL: http://host.docker.internal:8000/image_5162.png
# Objects full URL: http://host.docker.internal:8000/image_5773.png
# Objects full URL: http://host.docker.internal:8000/image_5987.png
# Objects full URL: http://host.docker.internal:8000/image_6042.png
# Objects full URL: http://host.docker.internal:8000/image_6262.png
# Objects full URL: http://host.docker.internal:8000/image_6404.png
# Objects full URL: http://host.docker.internal:8000/image_7036.png
# Objects full URL: http://host.docker.internal:8000/image_7081.png
# Objects full URL: http://host.docker.internal:8000/image_7445.png
# Objects full URL: http://host.docker.internal:8000/image_8041.png
# Objects full URL: http://host.docker.internal:8000/image_8094.png
# Objects full URL: http://host.docker.internal:8000/image_8353.png
# Objects full URL: http://host.docker.internal:8000/image_8371.png
# Objects full URL: http://host.docker.internal:8000/image_8525.png
# Objects full URL: http://host.docker.internal:8000/image_8792.png
# Objects full URL: http://host.docker.internal:8000/image_9300.png
# Objects full URL: http://host.docker.internal:8000/image_9303.png
# Objects full URL: http://host.docker.internal:8000/image_9621.png

# %%
# Optionally, save the updated DataFrame to a new TSV file.
output_tsv = "arcgis_img_captions_objects_final1.tsv"
df2.to_csv(output_tsv, sep="\t", index=False)
print("Captions and objects updated and saved to", output_tsv)
# Out:
# Captions and objects updated and saved to arcgis_img_captions_objects_final1.tsv

# %%
display(df2['objects'])
# Out:
# 0                   megalith, megalithic structure, cloak
# 1                                             trench coat
# 2       bannister, banister, balustrade, balusters, ha...
# 3                                      safe, sliding door
# 4         paddlewheel, paddle wheel, prison, prison house
#                               ...
# 9726                                               castle
# 9727                                     monastery, vault
# 9728                        prison, prison house, viaduct
# 9729                               basketball, volleyball
# 9730               whippet, dogsled, dog sled, dog sleigh
# Name: objects, Length: 9731, dtype: object
